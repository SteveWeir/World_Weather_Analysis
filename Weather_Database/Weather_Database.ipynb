# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# Import the requests library.
import requests

# Import datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats,lngs)
# The zip() function will combine the randomly generated lats/lngs points as PAIRS of data (based on index, forms a tuple)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient city count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Get city weather description.
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | lagoa
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | manggar
# Processing Record 8 of Set 1 | husavik
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | gat
# Processing Record 11 of Set 1 | eydhafushi
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | tazovskiy
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | jumilla
# Processing Record 19 of Set 1 | polunochnoye
# Processing Record 20 of Set 1 | sao miguel do araguaia
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | waipawa
# Processing Record 23 of Set 1 | kantang
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 1 | costa rica
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | zhigansk
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | hami
# Processing Record 33 of Set 1 | luau
# Processing Record 34 of Set 1 | coihaique
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | padang
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | saint-francois
# Processing Record 39 of Set 1 | hirara
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | brufut
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | olinda
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | invermere
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | kamloops
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | ketchikan
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | berlin
# Processing Record 20 of Set 2 | tacarigua
# Processing Record 21 of Set 2 | hobyo
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | bathsheba
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | kendari
# Processing Record 29 of Set 2 | nakhon thai
# Processing Record 30 of Set 2 | yulara
# Processing Record 31 of Set 2 | kudahuvadhoo
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | ahuimanu
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | tautira
# Processing Record 37 of Set 2 | bom jesus
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | antofagasta
# Processing Record 40 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | havre-saint-pierre
# Processing Record 44 of Set 2 | nyurba
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | nacala
# Processing Record 47 of Set 2 | puerto ayacucho
# Processing Record 48 of Set 2 | marang
# Processing Record 49 of Set 2 | alta floresta
# Processing Record 50 of Set 2 | moerai
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | san rafael del sur
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | tilichiki
# Processing Record 8 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 3 | biltine
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | yakeshi
# Processing Record 13 of Set 3 | tual
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | sana
# Processing Record 16 of Set 3 | payo
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | raga
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | malindi
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | broken hill
# Processing Record 28 of Set 3 | barauna
# Processing Record 29 of Set 3 | komsomolskiy
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | suntar
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | bilibino
# Processing Record 36 of Set 3 | bend
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | nargana
# Processing Record 39 of Set 3 | olafsvik
# Processing Record 40 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 41 of Set 3 | vostok
# Processing Record 42 of Set 3 | synya
# Processing Record 43 of Set 3 | oistins
# Processing Record 44 of Set 3 | maxixe
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | portales
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 4 | buala
# Processing Record 2 of Set 4 | mvuma
# Processing Record 3 of Set 4 | portland
# Processing Record 4 of Set 4 | pitimbu
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | mount isa
# Processing Record 7 of Set 4 | araouane
# Processing Record 8 of Set 4 | san policarpo
# Processing Record 9 of Set 4 | jacksonville
# Processing Record 10 of Set 4 | mehamn
# Processing Record 11 of Set 4 | hare bay
# Processing Record 12 of Set 4 | cuenca
# Processing Record 13 of Set 4 | rafaela
# Processing Record 14 of Set 4 | puteyets
# Processing Record 15 of Set 4 | kaeo
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | calbuco
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | diffa
# Processing Record 20 of Set 4 | rodino
# Processing Record 21 of Set 4 | spornoye
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | champerico
# Processing Record 24 of Set 4 | greymouth
# Processing Record 25 of Set 4 | vigrestad
# Processing Record 26 of Set 4 | slave lake
# Processing Record 27 of Set 4 | vestmanna
# Processing Record 28 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 4 | richards bay
# Processing Record 30 of Set 4 | cookeville
# Processing Record 31 of Set 4 | juliaca
# Processing Record 32 of Set 4 | pakxan
# Processing Record 33 of Set 4 | kumba
# Processing Record 34 of Set 4 | tchibanga
# Processing Record 35 of Set 4 | kruisfontein
# Processing Record 36 of Set 4 | gawler
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | grand gaube
# Processing Record 40 of Set 4 | lavrentiya
# Processing Record 41 of Set 4 | alice springs
# Processing Record 42 of Set 4 | boden
# Processing Record 43 of Set 4 | karema
# Processing Record 44 of Set 4 | qaqortoq
# Processing Record 45 of Set 4 | korla
# Processing Record 46 of Set 4 | namibe
# Processing Record 47 of Set 4 | atuona
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | ngunguru
# Processing Record 50 of Set 4 | kidal
# Processing Record 1 of Set 5 | ossora
# Processing Record 2 of Set 5 | laguna
# Processing Record 3 of Set 5 | port alfred
# Processing Record 4 of Set 5 | sabang
# Processing Record 5 of Set 5 | formosa
# Processing Record 6 of Set 5 | luanda
# Processing Record 7 of Set 5 | terrace
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | ambon
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | coro
# Processing Record 12 of Set 5 | lazaro cardenas
# Processing Record 13 of Set 5 | oranjemund
# Processing Record 14 of Set 5 | vizinga
# Processing Record 15 of Set 5 | bac ninh
# Processing Record 16 of Set 5 | ballina
# Processing Record 17 of Set 5 | krutinka
# Processing Record 18 of Set 5 | zholymbet
# Processing Record 19 of Set 5 | kieta
# Processing Record 20 of Set 5 | camana
# Processing Record 21 of Set 5 | sioux lookout
# Processing Record 22 of Set 5 | senador guiomard
# Processing Record 23 of Set 5 | omboue
# Processing Record 24 of Set 5 | tomatlan
# Processing Record 25 of Set 5 | inhambane
# Processing Record 26 of Set 5 | santa rosalia
# Processing Record 27 of Set 5 | la cruz
# Processing Record 28 of Set 5 | petauke
# Processing Record 29 of Set 5 | krasne
# Processing Record 30 of Set 5 | zhumadian
# Processing Record 31 of Set 5 | aleksandrov gay
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | clarence town
# Processing Record 34 of Set 5 | vanimo
# Processing Record 35 of Set 5 | roald
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | parabel
# Processing Record 38 of Set 5 | glendive
# Processing Record 39 of Set 5 | oussouye
# Processing Record 40 of Set 5 | novichikha
# Processing Record 41 of Set 5 | vilyuysk
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | redmond
# Processing Record 45 of Set 5 | salaga
# Processing Record 46 of Set 5 | poddorye
# Processing Record 47 of Set 5 | khani
# Processing Record 48 of Set 5 | price
# Processing Record 49 of Set 5 | creel
# Processing Record 50 of Set 5 | avarua
# Processing Record 1 of Set 6 | ancud
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | sampit
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | liverpool
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | chivay
# Processing Record 9 of Set 6 | vardo
# Processing Record 10 of Set 6 | marsa matruh
# Processing Record 11 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 6 | madang
# Processing Record 13 of Set 6 | wiarton
# Processing Record 14 of Set 6 | saquena
# Processing Record 15 of Set 6 | velasco ibarra
# Processing Record 16 of Set 6 | ulladulla
# Processing Record 17 of Set 6 | buraydah
# Processing Record 18 of Set 6 | sanchor
# Processing Record 19 of Set 6 | quesnel
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | torbay
# Processing Record 22 of Set 6 | rabaul
# Processing Record 23 of Set 6 | dalvik
# Processing Record 24 of Set 6 | saint-augustin
# Processing Record 25 of Set 6 | bose
# Processing Record 26 of Set 6 | eirunepe
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | port-de-bouc
# Processing Record 29 of Set 6 | bamberg
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | kahului
# Processing Record 33 of Set 6 | vryburg
# Processing Record 34 of Set 6 | livingston
# Processing Record 35 of Set 6 | manoel urbano
# Processing Record 36 of Set 6 | tondano
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | port blair
# Processing Record 39 of Set 6 | serebryanyy bor
# Processing Record 40 of Set 6 | los llanos de aridane
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | lagos
# Processing Record 43 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | vaitape
# Processing Record 46 of Set 6 | paramonga
# Processing Record 47 of Set 6 | christchurch
# Processing Record 48 of Set 6 | georgetown
# Processing Record 49 of Set 6 | port shepstone
# Processing Record 50 of Set 6 | tocopilla
# Processing Record 1 of Set 7 | muroto
# Processing Record 2 of Set 7 | matara
# Processing Record 3 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 7 | tete
# Processing Record 5 of Set 7 | paamiut
# Processing Record 6 of Set 7 | nelson bay
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | caravelas
# Processing Record 10 of Set 7 | amberieu-en-bugey
# Processing Record 11 of Set 7 | mbuyapey
# Processing Record 12 of Set 7 | tongzi
# Processing Record 13 of Set 7 | hammerfest
# Processing Record 14 of Set 7 | roebourne
# Processing Record 15 of Set 7 | berlevag
# Processing Record 16 of Set 7 | uhlirske janovice
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | erzin
# Processing Record 19 of Set 7 | cayenne
# Processing Record 20 of Set 7 | sept-iles
# Processing Record 21 of Set 7 | grand-santi
# Processing Record 22 of Set 7 | kodiak
# Processing Record 23 of Set 7 | zapolyarnyy
# Processing Record 24 of Set 7 | rawson
# Processing Record 25 of Set 7 | belyy yar
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | faya
# Processing Record 29 of Set 7 | hoa binh
# Processing Record 30 of Set 7 | ondjiva
# Processing Record 31 of Set 7 | blythe
# Processing Record 32 of Set 7 | shalya
# Processing Record 33 of Set 7 | antalaha
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | kirakira
# Processing Record 36 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 7 | chapada dos guimaraes
# Processing Record 39 of Set 7 | coulihaut
# City not found. Skipping...
# Processing Record 40 of Set 7 | nurota
# Processing Record 41 of Set 7 | kurilsk
# Processing Record 42 of Set 7 | santona
# Processing Record 43 of Set 7 | ibb
# Processing Record 44 of Set 7 | locri
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | marbella
# Processing Record 47 of Set 7 | sosua
# Processing Record 48 of Set 7 | ixtapa
# Processing Record 49 of Set 7 | rosarito
# Processing Record 50 of Set 7 | dunkirk
# Processing Record 1 of Set 8 | ibiruba
# Processing Record 2 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 3 of Set 8 | sorong
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | talara
# Processing Record 6 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 8 | port hedland
# Processing Record 8 of Set 8 | vysokopillya
# Processing Record 9 of Set 8 | darhan
# Processing Record 10 of Set 8 | singanallur
# Processing Record 11 of Set 8 | ahipara
# Processing Record 12 of Set 8 | mishelevka
# Processing Record 13 of Set 8 | canaries
# Processing Record 14 of Set 8 | te anau
# Processing Record 15 of Set 8 | pochutla
# Processing Record 16 of Set 8 | wagga wagga
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | qasigiannguit
# Processing Record 19 of Set 8 | vestmannaeyjar
# Processing Record 20 of Set 8 | verkhnevilyuysk
# Processing Record 21 of Set 8 | ilhabela
# Processing Record 22 of Set 8 | banda aceh
# Processing Record 23 of Set 8 | port hardy
# Processing Record 24 of Set 8 | namatanai
# Processing Record 25 of Set 8 | macae
# Processing Record 26 of Set 8 | ingham
# Processing Record 27 of Set 8 | tateyama
# Processing Record 28 of Set 8 | mosquera
# Processing Record 29 of Set 8 | emba
# Processing Record 30 of Set 8 | yellowknife
# Processing Record 31 of Set 8 | cape girardeau
# Processing Record 32 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 8 | colquiri
# Processing Record 34 of Set 8 | atasu
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | hauterive
# Processing Record 37 of Set 8 | fukue
# Processing Record 38 of Set 8 | zhuhai
# Processing Record 39 of Set 8 | tromso
# Processing Record 40 of Set 8 | dickson
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | nanortalik
# Processing Record 43 of Set 8 | poiana lacului
# Processing Record 44 of Set 8 | uskedal
# City not found. Skipping...
# Processing Record 45 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | karratha
# Processing Record 48 of Set 8 | basna
# Processing Record 49 of Set 8 | praia da vitoria
# Processing Record 50 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 9 | whitehorse
# Processing Record 2 of Set 9 | ipubi
# Processing Record 3 of Set 9 | cherskiy
# Processing Record 4 of Set 9 | lata
# Processing Record 5 of Set 9 | sabha
# Processing Record 6 of Set 9 | baijiantan
# Processing Record 7 of Set 9 | tessalit
# Processing Record 8 of Set 9 | knysna
# Processing Record 9 of Set 9 | ostersund
# Processing Record 10 of Set 9 | tamiahua
# Processing Record 11 of Set 9 | salcininkai
# Processing Record 12 of Set 9 | muli
# Processing Record 13 of Set 9 | san juan
# Processing Record 14 of Set 9 | kitimat
# Processing Record 15 of Set 9 | ranot
# Processing Record 16 of Set 9 | tchamba
# Processing Record 17 of Set 9 | keuruu
# Processing Record 18 of Set 9 | lithgow
# Processing Record 19 of Set 9 | shunyi
# Processing Record 20 of Set 9 | rancho palos verdes
# Processing Record 21 of Set 9 | malanje
# Processing Record 22 of Set 9 | gisborne
# Processing Record 23 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 26 of Set 9 | uchiza
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | bayan
# Processing Record 29 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 9 | barroso
# Processing Record 31 of Set 9 | baruun-urt
# Processing Record 32 of Set 9 | naryan-mar
# Processing Record 33 of Set 9 | samarai
# Processing Record 34 of Set 9 | houma
# Processing Record 35 of Set 9 | ishinomaki
# Processing Record 36 of Set 9 | povenets
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | altamira
# Processing Record 39 of Set 9 | san nicolas
# Processing Record 40 of Set 9 | makakilo city
# Processing Record 41 of Set 9 | alofi
# Processing Record 42 of Set 9 | adre
# Processing Record 43 of Set 9 | grindavik
# Processing Record 44 of Set 9 | moissala
# Processing Record 45 of Set 9 | pucallpa
# Processing Record 46 of Set 9 | severobaykalsk
# Processing Record 47 of Set 9 | tabuny
# Processing Record 48 of Set 9 | guane
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | toropets
# Processing Record 1 of Set 10 | kuusamo
# Processing Record 2 of Set 10 | hovd
# Processing Record 3 of Set 10 | flinders
# Processing Record 4 of Set 10 | rincon
# Processing Record 5 of Set 10 | svetlogorsk
# Processing Record 6 of Set 10 | mount gambier
# Processing Record 7 of Set 10 | dahra
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | key largo
# Processing Record 10 of Set 10 | ranchi
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | srikakulam
# Processing Record 13 of Set 10 | prince george
# Processing Record 14 of Set 10 | marawi
# Processing Record 15 of Set 10 | nazas
# Processing Record 16 of Set 10 | touzim
# Processing Record 17 of Set 10 | phonhong
# Processing Record 18 of Set 10 | tongchuan
# Processing Record 19 of Set 10 | olga
# Processing Record 20 of Set 10 | lipari
# Processing Record 21 of Set 10 | balaipungut
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | north bend
# Processing Record 24 of Set 10 | pampa
# Processing Record 25 of Set 10 | tombouctou
# Processing Record 26 of Set 10 | veraval
# Processing Record 27 of Set 10 | bac lieu
# Processing Record 28 of Set 10 | baljevac
# Processing Record 29 of Set 10 | camargo
# Processing Record 30 of Set 10 | brigantine
# Processing Record 31 of Set 10 | aras
# Processing Record 32 of Set 10 | ca mau
# Processing Record 33 of Set 10 | boxmeer
# Processing Record 34 of Set 10 | fairbanks
# Processing Record 35 of Set 10 | nha trang
# Processing Record 36 of Set 10 | guadalupe y calvo
# Processing Record 37 of Set 10 | okhotsk
# Processing Record 38 of Set 10 | saint-pierre
# Processing Record 39 of Set 10 | enshi
# Processing Record 40 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 10 | srandakan
# Processing Record 42 of Set 10 | pacific grove
# Processing Record 43 of Set 10 | saint-leu
# Processing Record 44 of Set 10 | beeville
# Processing Record 45 of Set 10 | kozhevnikovo
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | tadine
# Processing Record 48 of Set 10 | birao
# Processing Record 49 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 11 | yebaishou
# Processing Record 2 of Set 11 | ayagoz
# Processing Record 3 of Set 11 | lima
# Processing Record 4 of Set 11 | ascension
# Processing Record 5 of Set 11 | kawalu
# Processing Record 6 of Set 11 | ziniare
# Processing Record 7 of Set 11 | kissamos
# Processing Record 8 of Set 11 | saint anthony
# Processing Record 9 of Set 11 | belle fourche
# Processing Record 10 of Set 11 | amga
# Processing Record 11 of Set 11 | trincomalee
# Processing Record 12 of Set 11 | tall kayf
# Processing Record 13 of Set 11 | massakory
# Processing Record 14 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 11 | kabin buri
# Processing Record 16 of Set 11 | varlamovo
# Processing Record 17 of Set 11 | longyearbyen
# Processing Record 18 of Set 11 | beringovskiy
# Processing Record 19 of Set 11 | xunchang
# Processing Record 20 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | bo phloi
# Processing Record 23 of Set 11 | usinsk
# Processing Record 24 of Set 11 | ridgecrest
# Processing Record 25 of Set 11 | jumla
# Processing Record 26 of Set 11 | sola
# Processing Record 27 of Set 11 | agadir
# Processing Record 28 of Set 11 | khuldabad
# Processing Record 29 of Set 11 | prince rupert
# Processing Record 30 of Set 11 | mayor pablo lagerenza
# Processing Record 31 of Set 11 | marsh harbour
# Processing Record 32 of Set 11 | napier
# Processing Record 33 of Set 11 | khasan
# Processing Record 34 of Set 11 | katsuura
# Processing Record 35 of Set 11 | vila
# Processing Record 36 of Set 11 | kilinochchi
# Processing Record 37 of Set 11 | udachnyy
# Processing Record 38 of Set 11 | totness
# Processing Record 39 of Set 11 | aswan
# Processing Record 40 of Set 11 | kuytun
# Processing Record 41 of Set 11 | japura
# Processing Record 42 of Set 11 | holme
# Processing Record 43 of Set 11 | rio grande
# Processing Record 44 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 11 | logrono
# Processing Record 46 of Set 11 | lososina
# Processing Record 47 of Set 11 | shache
# Processing Record 48 of Set 11 | sayyan
# Processing Record 49 of Set 11 | fomboni
# Processing Record 50 of Set 11 | waycross
# Processing Record 1 of Set 12 | mananara
# Processing Record 2 of Set 12 | xifeng
# Processing Record 3 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 12 | san ignacio
# Processing Record 5 of Set 12 | miedzyrzecz
# Processing Record 6 of Set 12 | sobolevo
# Processing Record 7 of Set 12 | chapais
# Processing Record 8 of Set 12 | rio cuarto
# Processing Record 9 of Set 12 | mahon
# Processing Record 10 of Set 12 | valleyview
# Processing Record 11 of Set 12 | morrope
# Processing Record 12 of Set 12 | sechura
# Processing Record 13 of Set 12 | camapua
# Processing Record 14 of Set 12 | aleksandrovka
# Processing Record 15 of Set 12 | paratinga
# Processing Record 16 of Set 12 | soyo
# Processing Record 17 of Set 12 | dukat
# Processing Record 18 of Set 12 | aklavik
# Processing Record 19 of Set 12 | cabedelo
# Processing Record 20 of Set 12 | jibuti
# Processing Record 21 of Set 12 | nova olinda do norte
# Processing Record 22 of Set 12 | hambantota
# Processing Record 23 of Set 12 | tingo maria
# Processing Record 24 of Set 12 | skjervoy
# Processing Record 25 of Set 12 | leningradskiy
# Processing Record 26 of Set 12 | wote
# Processing Record 27 of Set 12 | muros
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | bonthe
# Processing Record 30 of Set 12 | byron bay
# Processing Record 31 of Set 12 | cukai
# Processing Record 32 of Set 12 | iskateley
# Processing Record 33 of Set 12 | outlook
# Processing Record 34 of Set 12 | barabai
# Processing Record 35 of Set 12 | laurel
# Processing Record 36 of Set 12 | nexo
# Processing Record 37 of Set 12 | juntas
# Processing Record 38 of Set 12 | yar-sale
# Processing Record 39 of Set 12 | chaohu
# Processing Record 40 of Set 12 | burayevo
# Processing Record 41 of Set 12 | kiruna
# Processing Record 42 of Set 12 | neuquen
# Processing Record 43 of Set 12 | cuamba
# Processing Record 44 of Set 12 | puerto rondon
# Processing Record 45 of Set 12 | elat
# Processing Record 46 of Set 12 | lichinga
# Processing Record 47 of Set 12 | luganville
# Processing Record 48 of Set 12 | benghazi
# Processing Record 49 of Set 12 | san carlos de bariloche
# Processing Record 50 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 13 | potosi
# Processing Record 2 of Set 13 | okhtyrka
# Processing Record 3 of Set 13 | tonantins
# Processing Record 4 of Set 13 | smithers
# Processing Record 5 of Set 13 | asau
# Processing Record 6 of Set 13 | suluova
# Processing Record 7 of Set 13 | odweyne
# Processing Record 8 of Set 13 | avera
# Processing Record 9 of Set 13 | diego de almagro
# Processing Record 10 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 13 | vilhena
# Processing Record 12 of Set 13 | berzence
# Processing Record 13 of Set 13 | homer
# Processing Record 14 of Set 13 | pemba
# Processing Record 15 of Set 13 | tabou
# Processing Record 16 of Set 13 | inverell
# Processing Record 17 of Set 13 | scottsbluff
# Processing Record 18 of Set 13 | pio xii
# Processing Record 19 of Set 13 | maniitsoq
# Processing Record 20 of Set 13 | bontang
# Processing Record 21 of Set 13 | hay river
# Processing Record 22 of Set 13 | grand haven
# Processing Record 23 of Set 13 | bagotville
# Processing Record 24 of Set 13 | seredka
# Processing Record 25 of Set 13 | oda
# Processing Record 26 of Set 13 | galveston
# Processing Record 27 of Set 13 | ocampo
# Processing Record 28 of Set 13 | geraldton
# Processing Record 29 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 13 | kyshtovka
# Processing Record 31 of Set 13 | piacabucu
# Processing Record 32 of Set 13 | waw
# Processing Record 33 of Set 13 | curitibanos
# Processing Record 34 of Set 13 | hargeysa
# Processing Record 35 of Set 13 | sidi qasim
# City not found. Skipping...
# Processing Record 36 of Set 13 | akyab
# Processing Record 37 of Set 13 | gotsu
# Processing Record 38 of Set 13 | lyuban
# Processing Record 39 of Set 13 | santiago de cao
# Processing Record 40 of Set 13 | parras
# City not found. Skipping...
# Processing Record 41 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 42 of Set 13 | anloga
# Processing Record 43 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 44 of Set 13 | medea
# Processing Record 45 of Set 13 | aberystwyth
# Processing Record 46 of Set 13 | warrnambool
# Processing Record 47 of Set 13 | agropoli
# Processing Record 48 of Set 13 | whitecourt
# Processing Record 49 of Set 13 | mbaiki
# Processing Record 50 of Set 13 | russell
# Processing Record 1 of Set 14 | caucaia
# Processing Record 2 of Set 14 | halifax
# Processing Record 3 of Set 14 | horn lake
# Processing Record 4 of Set 14 | ola
# Processing Record 5 of Set 14 | sarahan
# Processing Record 6 of Set 14 | dongsheng
# Processing Record 7 of Set 14 | macas
# Processing Record 8 of Set 14 | bambanglipuro
# Processing Record 9 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 14 | bubaque
# Processing Record 11 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 14 | tranas
# Processing Record 13 of Set 14 | ellsworth
# Processing Record 14 of Set 14 | balabac
# Processing Record 15 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 14 | lira
# Processing Record 17 of Set 14 | newton
# Processing Record 18 of Set 14 | ecija
# Processing Record 19 of Set 14 | khandbari
# Processing Record 20 of Set 14 | hervey bay
# Processing Record 21 of Set 14 | pavda
# City not found. Skipping...
# Processing Record 22 of Set 14 | santa maria
# Processing Record 23 of Set 14 | turukhansk
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | touba
# Processing Record 26 of Set 14 | wembley
# Processing Record 27 of Set 14 | kabinda
# Processing Record 28 of Set 14 | wencheng
# Processing Record 29 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 14 | aykhal
# Processing Record 31 of Set 14 | serenje
# Processing Record 32 of Set 14 | palimbang
# Processing Record 33 of Set 14 | pakxe
# Processing Record 34 of Set 14 | kazerun
# Processing Record 35 of Set 14 | chicama
# Processing Record 36 of Set 14 | denham springs
# Processing Record 37 of Set 14 | bowen
# Processing Record 38 of Set 14 | panzhihua
# Processing Record 39 of Set 14 | tarauaca
# Processing Record 40 of Set 14 | noyabrsk
# Processing Record 41 of Set 14 | mocuba
# Processing Record 42 of Set 14 | fazilka
# Processing Record 43 of Set 14 | pervomayskiy
# Processing Record 44 of Set 14 | bridlington
# Processing Record 45 of Set 14 | launceston
# Processing Record 46 of Set 14 | barberton
# Processing Record 47 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 14 | bud
# Processing Record 49 of Set 14 | opuwo
# Processing Record 50 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 15 | kismayo
# Processing Record 2 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 15 | teya
# Processing Record 4 of Set 15 | ilo
# Processing Record 5 of Set 15 | colac
# Processing Record 6 of Set 15 | strezhevoy
# Processing Record 7 of Set 15 | kologriv
# Processing Record 8 of Set 15 | ryotsu
# Processing Record 9 of Set 15 | old town
# Processing Record 10 of Set 15 | abbeville
# Processing Record 11 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 15 | oktyabrskoye
# Processing Record 13 of Set 15 | half moon bay
# Processing Record 14 of Set 15 | takhtamygda
# Processing Record 15 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 15 | gallup
# Processing Record 17 of Set 15 | sokoni
# Processing Record 18 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 15 | alamos
# Processing Record 20 of Set 15 | nemuro
# Processing Record 21 of Set 15 | acarau
# Processing Record 22 of Set 15 | cordoba
# Processing Record 23 of Set 15 | bosaso
# Processing Record 24 of Set 15 | sattahip
# Processing Record 25 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 15 | redcar
# Processing Record 27 of Set 15 | kathu
# Processing Record 28 of Set 15 | concepcion
# Processing Record 29 of Set 15 | sebrovo
# Processing Record 30 of Set 15 | bandarbeyla
# Processing Record 31 of Set 15 | kasama
# Processing Record 32 of Set 15 | haines junction
# Processing Record 33 of Set 15 | nishihara
# Processing Record 34 of Set 15 | mariestad
# Processing Record 35 of Set 15 | jinchang
# Processing Record 36 of Set 15 | natchitoches
# Processing Record 37 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 39 of Set 15 | emerald
# Processing Record 40 of Set 15 | naze
# Processing Record 41 of Set 15 | darnah
# Processing Record 42 of Set 15 | ratnagiri
# Processing Record 43 of Set 15 | verrettes
# Processing Record 44 of Set 15 | mastic beach
# Processing Record 45 of Set 15 | sandomierz
# Processing Record 46 of Set 15 | puerto quijarro
# Processing Record 47 of Set 15 | fevik
# Processing Record 48 of Set 15 | chernyshevskiy
# Processing Record 49 of Set 15 | grafton
# Processing Record 50 of Set 15 | eureka
# Processing Record 1 of Set 16 | yerbogachen
# Processing Record 2 of Set 16 | comodoro rivadavia
# Processing Record 3 of Set 16 | turtas
# Processing Record 4 of Set 16 | tucupita
# Processing Record 5 of Set 16 | seoul
# Processing Record 6 of Set 16 | kelo
# Processing Record 7 of Set 16 | ouahigouya
# Processing Record 8 of Set 16 | petrinja
# Processing Record 9 of Set 16 | aklera
# Processing Record 10 of Set 16 | vung tau
# Processing Record 11 of Set 16 | andenes
# Processing Record 12 of Set 16 | mangai
# Processing Record 13 of Set 16 | maloye kozino
# City not found. Skipping...
# Processing Record 14 of Set 16 | maryborough
# Processing Record 15 of Set 16 | moratuwa
# Processing Record 16 of Set 16 | polson
# Processing Record 17 of Set 16 | siena
# Processing Record 18 of Set 16 | petatlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     60.80        90          89
# 1          Poum      NC -20.2333  164.0167     74.82        66           2
# 2         Lagoa      PT  39.0500  -27.9833     69.28        90         100
# 3  Puerto Ayora      EC  -0.7393  -90.3518     68.56        94          40
# 4         Kapaa      US  22.0752 -159.3190     84.18        75          75
# 5       Manggar      ID  -2.8833  108.2667     86.11        66          76
# 6       Husavik      IS  66.0449  -17.3389     33.71        93         100
# 7   Provideniya      RU  64.3833 -173.3000     33.91        75          90
# 8           Gat      IL  31.6100   34.7642     69.40        74           0
# 9    Eydhafushi      MV   5.1033   73.0708     83.34        78          92
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       14.38           clear sky
# 2       19.15     overcast clouds
# 3        5.99    scattered clouds
# 4        3.00       broken clouds
# 5       11.16       broken clouds
# 6        3.65     overcast clouds
# 7       13.42     overcast clouds
# 8        4.21           clear sky
# 9       16.53     overcast clouds

# %%
# Add the data to a DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     60.80        90          89
# 1          Poum      NC -20.2333  164.0167     74.82        66           2
# 2         Lagoa      PT  39.0500  -27.9833     69.28        90         100
# 3  Puerto Ayora      EC  -0.7393  -90.3518     68.56        94          40
# 4         Kapaa      US  22.0752 -159.3190     84.18        75          75
# 5       Manggar      ID  -2.8833  108.2667     86.11        66          76
# 6       Husavik      IS  66.0449  -17.3389     33.71        93         100
# 7   Provideniya      RU  64.3833 -173.3000     33.91        75          90
# 8           Gat      IL  31.6100   34.7642     69.40        74           0
# 9    Eydhafushi      MV   5.1033   73.0708     83.34        78          92
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       14.38           clear sky
# 2       19.15     overcast clouds
# 3        5.99    scattered clouds
# 4        3.00       broken clouds
# 5       11.16       broken clouds
# 6        3.65     overcast clouds
# 7       13.42     overcast clouds
# 8        4.21           clear sky
# 9       16.53     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
